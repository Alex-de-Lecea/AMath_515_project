# %%
import torch
import torch.nn as nn
import torchvision
import numpy as np 
import matplotlib.pyplot as plt
from collections import OrderedDict
import Autoencoder as AE

# use GPU if available
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# Reproducibility  
torch.manual_seed(0);
# Out:
# C:\Users\dstre\AppData\Local\Temp\ipykernel_29056\2062129741.py:5: UserWarning: Treat the new Tool classes introduced in v1.5 as experimental for now; the API and rcParam may change in future versions.
#   import matplotlib.pyplot as plt

# %%
### Load Data ### 

#Use create a transform that uses bilinear interpolation to resize images to 64 square
im_size = 64
transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize(im_size),
    torchvision.transforms.ToTensor()
])

#load dataset and init dataloader (THIS WILL DOWNLOAD THE DATASET)
#dataloader will automatically batch and handle data
#The MNIST dataset is "premade," we will likely need to use TensorDataset to load our own datasets
mnist_dset_train = torchvision.datasets.MNIST(root = './data/', download=True, train = True, transform = transform)
batch_size = 128
mnist_DL = torch.utils.data.DataLoader(mnist_dset_train, shuffle=True, batch_size=batch_size)

# %%
#show sample
sample = next(iter(mnist_DL))  #grab the next batch from the dataloader
print('Image batch:', sample[0].shape) #of shape batch_size x channels x W x H (channels = 1 for this grayscale dset)  
plt.imshow(sample[0][0,0])    #show the image
plt.show()
# Out:
# Image batch: torch.Size([128, 1, 64, 64])

# %%
#initialize and test networks 
#make sure to send everything to the correct device (important if you have GPU)
n_latent = int(0.1 * (im_size**2)) #number of latent variables (10% of the input size)
n_hidden = 8 #number of hidden layers 
NN_width = n_latent * 8 #width of the hidden layers

net = AE.AutoEncoder(im_size**2, n_latent, n_hidden, NN_width, taper = True).to(device)
reconst, latent = net(sample[0].to(device))
print('Reconstructed shape:', reconst.shape)
print('Latent shape:', latent.shape)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 7
#       4 n_hidden = 8 #number of hidden layers
#       5 NN_width = n_latent * 8 #width of the hidden layers
# ----> 7 net = AE.AutoEncoder(im_size**2, n_latent, n_hidden, NN_width, taper = True).to(device)
#       8 reconst, latent = net(sample[0].to(device))
#       9 print('Reconstructed shape:', reconst.shape)
#
# File c:\Moat\Classes\Q2\AMATH 515 - Optimization\AMath_515_project\Autoencoder.py:101, in AutoEncoder.__init__(self, im_size, n_latent, n_hidden, NN_width, taper)
#      99 def __init__(self, im_size, n_latent, n_hidden, NN_width, taper = False):
#     100     super(AutoEncoder, self).__init__()
# --> 101     self.encoder = Encoder(im_size, n_latent, n_hidden, NN_width, taper = taper)
#     102     self.decoder = Decoder(im_size, n_latent, n_hidden, NN_width, taper = taper)
#
# File c:\Moat\Classes\Q2\AMATH 515 - Optimization\AMath_515_project\Autoencoder.py:18, in Encoder.__init__(self, im_size, n_latent, n_hidden, NN_width, taper)
#      15 super(Encoder, self).__init__()
#      17 #create input layer
# ---> 18 self.l1 = nn.Linear(im_size**2, NN_width)
#      19 self.a1 = nn.LeakyReLU(0.2, inplace=True)
#      21 #create hidden layers
#
# File c:\Users\dstre\miniconda3\envs\torch\Lib\site-packages\torch\nn\modules\linear.py:96, in Linear.__init__(self, in_features, out_features, bias, device, dtype)
#      94 self.in_features = in_features
#      95 self.out_features = out_features
# ---> 96 self.weight = Parameter(torch.empty((out_features, in_features), **factory_kwargs))
#      97 if bias:
#      98     self.bias = Parameter(torch.empty(out_features, **factory_kwargs))
#
# RuntimeError: [enforce fail at alloc_cpu.cpp:80] data. DefaultCPUAllocator: not enough memory: you tried to allocate 219580203008 bytes.

# %%
#training parameters
epochs = 3        #one epoch is one iteration through the entire training cylce
iters_cycle = 100    #frequency of which to log results
error = torch.nn.MSELoss()

# %%
### Train Autoencoder ###
LR = 0.0001

#initialize error function and optimizer
opt = torch.optim.Adam(net.parameters(), betas=(0.5, 0.999), lr = LR)

#save losses
losses = []

#train
iters = 0

for epoch in range(epochs):
    #iterate through dataloader
    for batch in mnist_DL:
        #separate batch into labels and images
        images = batch[0].to(device)
        
        #make predictions
        reconst, latent = net(images)
        
        #calculate loss
        loss = error(reconst, images)
        
        #backpropagate gradients with Adam algorithm, this is the magic of pytorch and autograd
        loss.backward()
        opt.step()
        
        #reset gradients
        net.zero_grad()
        
        #save losses
        losses.append(loss.item())
        
        #log progress
        if iters%iters_cycle==0:    
            print('Epoch: {}/{}     Iter: {}     Loss: {}'.format(epoch, epochs, iters, loss.item()))
        iters +=1
# Out:
# Epoch: 0/3     Iter: 0     Loss: 0.10403333604335785
# Epoch: 0/3     Iter: 100     Loss: 0.05653437227010727
# Epoch: 0/3     Iter: 200     Loss: 0.054612334817647934
# Epoch: 0/3     Iter: 300     Loss: 0.05160658061504364
# Epoch: 0/3     Iter: 400     Loss: 0.04775508865714073
# Epoch: 1/3     Iter: 500     Loss: 0.043291471898555756
# Epoch: 1/3     Iter: 600     Loss: 0.04628773778676987
# Epoch: 1/3     Iter: 700     Loss: 0.044614292681217194
# Epoch: 1/3     Iter: 800     Loss: 0.05272696167230606
# Epoch: 1/3     Iter: 900     Loss: 0.04625367000699043
# Epoch: 2/3     Iter: 1000     Loss: 0.04363931715488434
# Epoch: 2/3     Iter: 1100     Loss: 0.039997249841690063
# Epoch: 2/3     Iter: 1200     Loss: 0.041746631264686584
# Epoch: 2/3     Iter: 1300     Loss: 0.03681398183107376
# Epoch: 2/3     Iter: 1400     Loss: 0.03456959128379822

# %%
#plot loss curve 
plt.figure(figsize = (8,6))
plt.plot(losses)
plt.xlabel('Iterations')
plt.ylabel('MSE Loss')
plt.yscale('log')
plt.show()

# %%
#Create test dataset and load into dataloader
mnist_dset_test = torchvision.datasets.MNIST(root = './data/MNIST/', download=True, train = False, transform = transform)
num_samples = 500
mnist_DL_test = torch.utils.data.DataLoader(mnist_dset_test, shuffle=True, batch_size=num_samples)

#display sample with label and prediction
sample = next(iter(mnist_DL_test))
reconst, latent = net(sample[0].to(device))

# show image and reconstruction side by side 
fig, ax = plt.subplots(1,2, figsize = (8,4))
ax[0].imshow(sample[0][0,0])
ax[0].set_title('Original')
ax[1].imshow(reconst[0,0].detach().cpu())
ax[1].set_title('Reconstructed with n_latent = ' + str(n_latent))
plt.show()

print("Reconstruction Error: ", error(reconst, sample[0].to(device)).item())
# Out:
# Reconstruction Error:  0.03282976895570755
